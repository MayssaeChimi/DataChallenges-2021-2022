# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Mounted at /content/gdrive
#  000.pdf
# '00H-prepa-math-exo et prb.pdf'
# '00Math_matiques Les exercices incontournables MP_nodrm.pdf'
#  00Math_matiques_M_thodes_et_Exercices_MP.pdf
# '00Physique Exercices incontournables MP-PT_nodrm.pdf'
#  05_Reduction_Corrige.pdf
#  1312.pdf
# '2021 Student Press Release (1).docx'
# '2021 Student Press Release (2).docx'
# '2021 Student Press Release.docx'
# 'algebre pr ds (1).pdf'
# 'algebre pr ds (2).pdf'
# 'algebre pr ds.pdf'
# 'All Part of Results.mp4'
#  AMMAN_2021_WELCOMEGUIDE_V1.pdf
#  apache-maven-3.5.0-bin.tar.gz
#  appsheet
# 'ATT CHIMI MAYSSAE (1).pdf'
# 'ATT CHIMI MAYSSAE.pdf'
#  awards_dasec.gdoc
#  bank.pdf
# 'Base de donneés pour recherche de stage..gsheet'
#  bibii7
#  bilan_dad.jpg
#  Books
#  Brainwash_Yourself_In_21_Days_for_Success_Use_this.mp4
# 'cahier de charge (1).docx'
# 'Candidature Spontannée  DB.gsheet'
# 'Carrières _ Déclarer mon stage.pdf'
#  ccp-francais-2018e.pdf
#  ccp.pdf
# ...

# %%
# %cd /mydrive/OCR/darknet
# Out:
# /content/gdrive/.shortcut-targets-by-id/1AUlgUAlPrsCKkrrGpDyk0m8K8sV5ibKy/OCR/darknet

# %%
# !chmod +x ./darknet

# %%
# !./darknet detector map data/obj.data cfg/yolov4-obj.cfg /mydrive/OCR/backup/yolov4-obj_last.weights
# Out:
#  CUDA-version: 11010 (11020), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 370, cudnn_half = 0, GPU: Tesla K80
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    3 route  1 		                           ->  208 x 208 x  64
#    4 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    5 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    6 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
# ...

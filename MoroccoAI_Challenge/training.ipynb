# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# Out:
# Mounted at /content/gdrive

# %%
# %cd /mydrive/OCR/darknet
# Out:
# /content/gdrive/My Drive/OCR/darknet

# %%
# !chmod +x ./darknet

# %%
#!./darknet detector map data/obj.data cfg/yolov4-obj.cfg /mydrive/OCR/backup/yolov4-obj_best.weights
# kick off training from where it last saved
# !./darknet detector train data/obj.data /content/gdrive/MyDrive/OCR/yolov4-obj.cfg /mydrive/OCR/backup/yolov4-obj_last.weights -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.780502), count: 68, class_loss = 1.300912, iou_loss = 23.064058, total_loss = 24.364971
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.765913), count: 4, class_loss = 0.070908, iou_loss = 0.344225, total_loss = 0.415133
#  total_bbox = 740828, rewritten_bbox = 0.033071 %
#
#  2733: 3.521660, 4.024081 avg loss, 0.001000 rate, 8.666352 seconds, 174912 images, 143.197102 hours left
# Loaded: 0.000077 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.774438), count: 86, class_loss = 15.083517, iou_loss = 94.268257, total_loss = 109.351776
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.798081), count: 129, class_loss = 9.525192, iou_loss = 44.701355, total_loss = 54.226547
# ...
